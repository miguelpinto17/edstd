# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row
from delta import *
from pyspark.sql.functions import col, when, count
from pyspark.sql.types import DoubleType, StringType, StructField, StructType, IntegerType, FloatType

# warehouse_location points to the default location for managed databases and tables
warehouse_location = 'hdfs://hdfs-nn:9000/warehouse'

builder = SparkSession \
    .builder \
    .master("local[2]") \
    .appName("Python Spark DataFrames and SQL") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .config("hive.metastore.uris", "thrift://hive-metastore:9083") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .config("spark.jars.packages", "io.delta:delta-core_2.12:2.4.0") \
    .enableHiveSupport() \

spark = builder.getOrCreate() #spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
hdfs_path = "hdfs://hdfs-nn:9000/projeto/bronze/Shootings_NY.csv"

# %%
shoot = spark.read.option("header", True) \
    .csv(hdfs_path)

shoot.show()
# Out:
# +------------+----------+----------+---------+-----------------+--------+-----------------+------------------+--------------------+-----------------------+--------------+--------+--------------------+-------------+-------+--------------------+----------+----------+-----------+------------+------------------------+
# |INCIDENT_KEY|OCCUR_DATE|OCCUR_TIME|     BORO|LOC_OF_OCCUR_DESC|PRECINCT|JURISDICTION_CODE|LOC_CLASSFCTN_DESC|       LOCATION_DESC|STATISTICAL_MURDER_FLAG|PERP_AGE_GROUP|PERP_SEX|           PERP_RACE|VIC_AGE_GROUP|VIC_SEX|            VIC_RACE|X_COORD_CD|Y_COORD_CD|   Latitude|   Longitude|New Georeferenced Column|
# +------------+----------+----------+---------+-----------------+--------+-----------------+------------------+--------------------+-----------------------+--------------+--------+--------------------+-------------+-------+--------------------+----------+----------+-----------+------------+------------------------+
# |   269311789|06/04/2023|  21:01:00|   QUEENS|          OUTSIDE|     109|                0|            STREET|              (null)|                      N|         45-64|       M|      WHITE HISPANIC|        25-44|      M|      WHITE HISPANIC|   1032051|    217053|       null|        null|                    null|
# |   269307857|06/04/2023|  00:20:00| BROOKLYN|          OUTSIDE|      75|                0|            STREET|              (null)|                      Y|         25-44|       M|               BLACK|        25-44|      M|               BLACK|   1017036|    183890|       null|        null|                    null|
# |   265303128|03/18/2023|  03:45:00|   QUEENS|          OUTSIDE|     102|                0|             OTHER|            HOSPITAL|                      N|         25-44|       M|               BLACK|        25-44|      M|               BLACK|   1030953|    194101|       null|        null|                    null|
# |   263482956|02/12/2023|  01:13:00|MANHATTAN|          OUTSIDE|      33|                0|             OTHER|            HOSPITAL|                      N|        (null)|  (null)|              (null)|        25-44|      M|               BLACK|   1000795|    245489|  40.840472|  -73.940202|    POINT (-73.940202...|
# |   262586366|01/26/2023|  18:23:00| BROOKLYN|          OUTSIDE|      69|                0|            STREET|              (null)|                      N|         25-44|       M|               BLACK|        25-44|      M|               BLACK|   1011203|    174514|  40.645639|  -73.902874|    POINT (-73.902874...|
# |   268295740|05/15/2023|  20:41:00|   QUEENS|          OUTSIDE|     113|                0|            STREET|              (null)|                      N|         25-44|       M|      BLACK HISPANIC|        25-44|      M|               BLACK|   1040097|    186349|  40.677988|  -73.798655|    POINT (-73.798655...|
# |   268302279|05/15/2023|  19:30:00| BROOKLYN|          OUTSIDE|      79|                0|            STREET|              (null)|                      N|        (null)|  (null)|              (null)|        25-44|      M|               BLACK|    999516|    192804|  40.695867|  -73.944946|    POINT (-73.944946...|
# |   267492349|04/29/2023|  21:49:00| BROOKLYN|          OUTSIDE|      66|                0|            STREET|              (null)|                      N|         45-64|       M|ASIAN / PACIFIC I...|        25-44|      M|ASIAN / PACIFIC I...|    982070|    170773|   40.63541|  -74.007852|    POINT (-74.007852...|
# |   269184588|06/01/2023|  20:18:00|    BRONX|          OUTSIDE|      44|                0|            STREET|              (null)|                      N|         18-24|       M|               BLACK|        18-24|      M|               BLACK|   1008787|    243961|  40.836258|  -73.911326|    POINT (-73.911326...|
# |   265354835|03/19/2023|  23:48:00|    BRONX|           INSIDE|      47|                0|        COMMERCIAL|      GROCERY/BODEGA|                      N|         25-44|       M|      WHITE HISPANIC|        25-44|      M|               BLACK|   1025687|    268586|  40.903785|  -73.850098|    POINT (-73.850098...|
# |   264262260|02/26/2023|  18:06:00|   QUEENS|          OUTSIDE|     113|                2|           HOUSING|MULTI DWELL - PUB...|                      N|         25-44|       M|               BLACK|        25-44|      F|               BLACK|   1044258|    189029|  40.685317|   -73.78363|    POINT (-73.78363 ...|
# |   264838131|01/27/2023|  18:00:00| BROOKLYN|           INSIDE|      81|                0|          DWELLING|MULTI DWELL - APT...|                      Y|         45-64|       M|               BLACK|        25-44|      M|               BLACK|   1004918|    190071|  40.688354|  -73.925473|    POINT (-73.925473...|
# |   262334288|01/21/2023|  21:17:00| BROOKLYN|          OUTSIDE|      63|                0|            STREET|              (null)|                      Y|         25-44|       M|               BLACK|        25-44|      M|               BLACK|   1003231|    167629|  40.626762|  -73.931618|    POINT (-73.931618...|
# |   261307948|01/03/2023|  03:19:00| BROOKLYN|           INSIDE|      72|                0|        COMMERCIAL|      BAR/NIGHT CLUB|                      N|         25-44|       M|      WHITE HISPANIC|        45-64|      M|      WHITE HISPANIC|    982383|    177997|  40.655237|  -74.006726|    POINT (-74.006726...|
# |   266896911|04/18/2023|  06:21:00| BROOKLYN|          OUTSIDE|      69|                0|            STREET|              (null)|                      N|         45-64|       M|               BLACK|        45-64|      M|               BLACK|   1014772|    176527|40.65114986|-73.89000444|    POINT (-73.890004...|
# |   264657996|03/06/2023|  19:50:00| BROOKLYN|          OUTSIDE|      81|                0|            STREET|              (null)|                      N|         25-44|       M|               BLACK|        25-44|      M|               BLACK|    986638|    193879|   40.69883|  -73.991388|    POINT (-73.991388...|
# |   267859151|05/06/2023|  04:30:00|    BRONX|          OUTSIDE|      48|                0|            STREET|      BAR/NIGHT CLUB|                      Y|         25-44|       M|      WHITE HISPANIC|        18-24|      M|      BLACK HISPANIC|   1013434|    248939|  40.849909|  -73.894509|    POINT (-73.894509...|
# |   270078983|06/19/2023|  17:49:00| BROOKLYN|          OUTSIDE|      79|                0|            STREET|MULTI DWELL - APT...|                      Y|        (null)|  (null)|              (null)|          <18|      M|               BLACK|   1000794|    192312|  40.694515|  -73.940339|    POINT (-73.940339...|
# |   262270874|01/20/2023|  22:25:00|MANHATTAN|           INSIDE|       5|                2|           HOUSING|MULTI DWELL - PUB...|                      N|         25-44|       M|               BLACK|        45-64|      F|      WHITE HISPANIC|    987136|    202242|  40.721784|  -73.989585|    POINT (-73.989585...|
# |   265417230|03/21/2023|  00:40:00|    BRONX|          OUTSIDE|      41|                0|            STREET|              (null)|                      N|        (null)|  (null)|              (null)|        25-44|      M|               BLACK|   1012918|    240579|  40.826963|  -73.896413|    POINT (-73.896413...|
# +------------+----------+----------+---------+-----------------+--------+-----------------+------------------+--------------------+-----------------------+--------------+--------+--------------------+-------------+-------+--------------------+----------+----------+-----------+------------+------------------------+
# only showing top 20 rows

# %%
nomes_colunas = shoot.columns

# Apresente os nomes das colunas
print("Nomes das Colunas:")
for nome_coluna in nomes_colunas:
    print(nome_coluna)
# Out:
# Nomes das Colunas:
# INCIDENT_KEY
# OCCUR_DATE
# OCCUR_TIME
# BORO
# LOC_OF_OCCUR_DESC
# PRECINCT
# JURISDICTION_CODE
# LOC_CLASSFCTN_DESC
# LOCATION_DESC
# STATISTICAL_MURDER_FLAG
# PERP_AGE_GROUP
# PERP_SEX
# PERP_RACE
# VIC_AGE_GROUP
# VIC_SEX
# VIC_RACE
# X_COORD_CD
# Y_COORD_CD
# Latitude
# Longitude
# New Georeferenced Column

# %%
shoot = shoot.fillna("Unknown")
shoot = shoot.replace("(null)", None).fillna("Unknown")
# Exibir o DataFrame resultante
shoot.show()
shoot.toPandas()
# Out:
# +------------+----------+----------+---------+-----------------+--------+-----------------+------------------+--------------------+-----------------------+--------------+--------
# 3      263482956  02/12/2023   01:13:00  MANHATTAN           OUTSIDE       33
# 4      262586366  01/26/2023   18:23:00   BROOKLYN           OUTSIDE       69
# ..           ...         ...        ...        ...               ...      ...
# 622    261964438  01/15/2023   23:23:00   BROOKLYN           OUTSIDE       81
# 623    270033866  06/18/2023   02:54:00  MANHATTAN           OUTSIDE        7
# 624    262409423  01/24/2023   01:05:00   BROOKLYN            INSIDE       73
# 625    262334288  01/21/2023   21:17:00   BROOKLYN           OUTSIDE       63
# 626    268199268  05/13/2023   02:20:00     QUEENS           OUTSIDE      114
#
#     JURISDICTION_CODE LOC_CLASSFCTN_DESC              LOCATION_DESC  \
# 0                   0             STREET                    Unknown
# 1                   0             STREET                    Unknown
# 2                   0              OTHER                   HOSPITAL
# 3                   0              OTHER                   HOSPITAL
# 4                   0             STREET                    Unknown
# ..                ...                ...                        ...
# 622                 0             STREET                    Unknown
# 623                 0             STREET                    Unknown
# 624                 0            HOUSING  MULTI DWELL - PUBLIC HOUS
# 625                 0             STREET                    Unknown
# 626                 2            HOUSING  MULTI DWELL - PUBLIC HOUS
#
#     STATISTICAL_MURDER_FLAG  ... PERP_SEX       PERP_RACE VIC_AGE_GROUP  \
# 0                         N  ...        M  WHITE HISPANIC         25-44
# 1                         Y  ...        M           BLACK         25-44
# 2                         N  ...        M           BLACK         25-44
# 3                         N  ...  Unknown         Unknown         25-44
# 4                         N  ...        M           BLACK         25-44
# ..                      ...  ...      ...             ...           ...
# 622                       N  ...  Unknown         Unknown         25-44
# 623                       N  ...        M           BLACK         25-44
# 624                       N  ...        M           BLACK         25-44
# 625                       Y  ...        M           BLACK         25-44
# 626                       N  ...        M           BLACK         25-44
#
#     VIC_SEX        VIC_RACE X_COORD_CD Y_COORD_CD     Latitude     Longitude  \
# 0         M  WHITE HISPANIC    1032051     217053      Unknown       Unknown
# 1         M           BLACK    1017036     183890      Unknown       Unknown
# 2         M           BLACK    1030953     194101      Unknown       Unknown
# 3         M           BLACK    1000795     245489    40.840472    -73.940202
# 4         M           BLACK    1011203     174514    40.645639    -73.902874
# ..      ...             ...        ...        ...          ...           ...
# 622       M           BLACK    1002314     186877  40.67959248  -73.93487298
# 623       M           BLACK     987431     202125  40.72146254  -73.98852418
# 624       M           BLACK    1009904     180751    40.662761    -73.907529
# 625       M           BLACK    1003231     167629    40.626762    -73.931618
# 626       F           BLACK    1001899     221193    40.773785    -73.936279
#
#              New Georeferenced Column
# 0                             Unknown
# 1                             Unknown
# 2                             Unknown
# 3        POINT (-73.940202 40.840472)
# 4        POINT (-73.902874 40.645639)
# ..                                ...
# 622  POINT (-73.93487298 40.67959248)
# 623  POINT (-73.98852418 40.72146254)
# 624      POINT (-73.907529 40.662761)
# 625      POINT (-73.931618 40.626762)
# 626      POINT (-73.936279 40.773785)
#
# [627 rows x 21 columns]

# %%
shoot = (
    shoot
    .withColumnRenamed("VIC_SEX", "Vic_Sex")
    .withColumnRenamed("INCIDENT_KEY", "Incident_Key")
    .withColumnRenamed("OCCUR_DATE", "Occur_Date")
    .withColumnRenamed("OCCUR_TIME", "Occur_Time")
    .withColumnRenamed("BORO", "Borough")
    .withColumnRenamed("LOC_OF_OCCUR_DESC", "Location")
    .withColumnRenamed("PRECINCT", "Area")
    .withColumnRenamed("JURISDICTION_CODE", "Jurisdiction_Code")
    .withColumnRenamed("LOC_CLASSFCTN_DESC", "Location_Classification")
    .withColumnRenamed("LOCATION_DESC", "Location_Desc")
    .withColumnRenamed("STATISTICAL_MURDER_FLAG", "Statistical_Murder_Flag")
    .withColumnRenamed("PERP_AGE_GROUP", "Perp_Age_Group")
    .withColumnRenamed("PERP_SEX", "Gender")
    .withColumnRenamed("PERP_RACE", "Perp_Race")
    .withColumnRenamed("VIC_AGE_GROUP", "Vic_Age_Group")
    .withColumnRenamed("VIC_RACE", "Vic_Race")
    .withColumnRenamed("X_COORD_CD", "X_Coord_Cd")
    .withColumnRenamed("Y_COORD_CD", "Y_Coord_Cd")
    .withColumnRenamed("Latitude", "Latitude")
    .withColumnRenamed("Longitude", "Longitude")
    .withColumnRenamed("New Georeferenced Column", "New_Georeferenced_Column")
)

# %%
shoot= (
    shoot
    .withColumn("Gender", 
                when(col("Gender") == "M", "Male")
                .when(col("Gender") == "F", "Female")
                .otherwise("Unknown"))
)

# %%
nomes_colunas = shoot.columns

# Apresente os nomes das colunas
print("Nomes das Colunas:")
for nome_coluna in nomes_colunas:
    print(nome_coluna)
# Out:
# Nomes das Colunas:
# Incident_Key
# Occur_Date
# Occur_Time
# Borough
# Location
# Area
# Jurisdiction_Code
# Location_Classification
# Location_Desc
# Statistical_Murder_Flag
# Perp_Age_Group
# Gender
# Perp_Race
# Vic_Age_Group
# Vic_Sex
# Vic_Race
# X_Coord_Cd
# Y_Coord_Cd
# Latitude
# Longitude
# New_Georeferenced_Column

# %%
column_data_types = {
    "Area": IntegerType(),
    "Jurisdiction_Code": IntegerType(),
    "X_Coord_Cd": IntegerType(),
    "Y_Coord_Cd": IntegerType(),
    "Incident_Key": StringType(),
    "Occur_Date": StringType(),
    "Occur_Time": StringType(),
    "Borough": StringType(),
    "Location": StringType(),
    "Location_Classification": StringType(),
    "Location_Desc": StringType(),
    "Statistical_Murder_Flag": StringType(),
    "Perp_Age_Group": StringType(),
    "Gender": StringType(),
    "Perp_Race": StringType(),
    "Vic_Age_Group": StringType(),
    "Vic_Sex": StringType(),
    "Vic_Race": StringType(),
    "Longitude": StringType(),
    "Latitude": StringType(),
    "New_Georeferenced_Column": StringType(),
}

# Aplicar a conversão de tipos de dados para cada coluna
shoot_converted = shoot
for col_name, data_type in column_data_types.items():
    shoot_converted = shoot_converted.withColumn(col_name, col(col_name).cast(data_type))

shoot_converted.write.format("delta").mode("overwrite").option("mergeSchema", "true").save("hdfs://hdfs-nn:9000/warehouse/projeto.db/Shootings_NY")

# %%
spark.sql(
    """
    SELECT * FROM projeto.shootings_NY
    """
).show()
# Out:
# +----+-----------------+----------+----------+------------+----------+----------+---------+--------+-----------------------+--------------------+-----------------------+--------------+-------+--------------------+-------------+-------+--------------------+------------+-----------+------------------------+
# 4      262586366  01/26/2023   18:23:00   BROOKLYN  OUTSIDE   69
# ..           ...         ...        ...        ...      ...  ...
# 622    261964438  01/15/2023   23:23:00   BROOKLYN  OUTSIDE   81
# 623    270033866  06/18/2023   02:54:00  MANHATTAN  OUTSIDE    7
# 624    262409423  01/24/2023   01:05:00   BROOKLYN   INSIDE   73
# 625    262334288  01/21/2023   21:17:00   BROOKLYN  OUTSIDE   63
# 626    268199268  05/13/2023   02:20:00     QUEENS  OUTSIDE  114
#
#     Jurisdiction_Code Location_Classification              Location_Desc  \
# 0                   0                  STREET                    Unknown
# 1                   0                  STREET                    Unknown
# 2                   0                   OTHER                   HOSPITAL
# 3                   0                   OTHER                   HOSPITAL
# 4                   0                  STREET                    Unknown
# ..                ...                     ...                        ...
# 622                 0                  STREET                    Unknown
# 623                 0                  STREET                    Unknown
# 624                 0                 HOUSING  MULTI DWELL - PUBLIC HOUS
# 625                 0                  STREET                    Unknown
# 626                 2                 HOUSING  MULTI DWELL - PUBLIC HOUS
#
#     Statistical_Murder_Flag  ...   Gender       Perp_Race Vic_Age_Group  \
# 0                         N  ...     Male  WHITE HISPANIC         25-44
# 1                         Y  ...     Male           BLACK         25-44
# 2                         N  ...     Male           BLACK         25-44
# 3                         N  ...  Unknown         Unknown         25-44
# 4                         N  ...     Male           BLACK         25-44
# ..                      ...  ...      ...             ...           ...
# 622                       N  ...  Unknown         Unknown         25-44
# 623                       N  ...     Male           BLACK         25-44
# 624                       N  ...     Male           BLACK         25-44
# 625                       Y  ...     Male           BLACK         25-44
# 626                       N  ...     Male           BLACK         25-44
#
#     Vic_Sex        Vic_Race X_Coord_Cd Y_Coord_Cd     Latitude     Longitude  \
# 0         M  WHITE HISPANIC    1032051     217053      Unknown       Unknown
# 1         M           BLACK    1017036     183890      Unknown       Unknown
# 2         M           BLACK    1030953     194101      Unknown       Unknown
# 3         M           BLACK    1000795     245489    40.840472    -73.940202
# 4         M           BLACK    1011203     174514    40.645639    -73.902874
# ..      ...             ...        ...        ...          ...           ...
# 622       M           BLACK    1002314     186877  40.67959248  -73.93487298
# 623       M           BLACK     987431     202125  40.72146254  -73.98852418
# 624       M           BLACK    1009904     180751    40.662761    -73.907529
# 625       M           BLACK    1003231     167629    40.626762    -73.931618
# 626       F           BLACK    1001899     221193    40.773785    -73.936279
#
#              New_Georeferenced_Column
# 0                             Unknown
# 1                             Unknown
# 2                             Unknown
# 3        POINT (-73.940202 40.840472)
# 4        POINT (-73.902874 40.645639)
# ..                                ...
# 622  POINT (-73.93487298 40.67959248)
# 623  POINT (-73.98852418 40.72146254)
# 624      POINT (-73.907529 40.662761)
# 625      POINT (-73.931618 40.626762)
# 626      POINT (-73.936279 40.773785)
#
# [627 rows x 21 columns]

# %%
gender_counts = shoot.groupBy("Gender").agg(count("*").alias("Count"))

# Imprima os resultados
print("Gender Counts:")
gender_counts.show()
# Out:
# Gender Counts:
# +-------+-----+
# | Gender|Count|
# +-------+-----+
# | Female|   12|
# |Unknown|  257|
# |   Male|  358|
# +-------+-----+
